# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_excel('global_laptop_selling_data.xlsx')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB  \
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  \
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %% [markdown]
# # Data Analysis

# %%
df.dtypes
# Out:
# laptop_ID             int64
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.columns
# Out:
# Index(['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_euros'],
#       dtype='object')

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.corr(numeric_only = True)
# Out:
#              laptop_ID    Inches  Price_euros
# laptop_ID     1.000000 -0.087796     0.067830
# Inches       -0.087796  1.000000     0.068197
# Price_euros   0.067830  0.068197     1.000000

# %%
df.nunique()
# Out:
# laptop_ID           1303
# Company               19
# Product              618
# TypeName               6
# Inches                18
# ScreenResolution      40
# Cpu                  118
# Ram                    9
# Memory                39
# Gpu                  106
# OpSys                  9
# Weight               179
# Price_euros          791
# dtype: int64

# %%
df1= df.copy()
df2= df.copy()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Scalling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn = MinMaxScaler(feature_range=(0,1))

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB  \
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  \
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df['laptop_ID'] = mn.fit_transform(df[['laptop_ID']])
df['Inches'] = mn.fit_transform(df[['Inches']])
df['Price_euros'] = mn.fit_transform(df[['Price_euros']])

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName    Inches
# 0   0.000000   Apple  MacBook Pro  Ultrabook  0.385542  \
# 1   0.000758   Apple  Macbook Air  Ultrabook  0.385542
# 2   0.001516      HP       250 G6   Notebook  0.662651
# 3   0.002274   Apple  MacBook Pro  Ultrabook  0.638554
# 4   0.003033   Apple  MacBook Pro  Ultrabook  0.385542
#
#                      ScreenResolution                         Cpu   Ram
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB  \
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  \
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0     0.196741
# 1     0.122353
# 2     0.067679
# 3     0.398895
# 4     0.275038

# %% [markdown]
# # Visualization

# %%
import seaborn as sns

# %%
plt.figure(figsize = (20, 10))
sns.histplot(df['Price_euros'])
# Out:
# <Axes: xlabel='Price_euros', ylabel='Count'>

# %%
plt.figure(figsize = (20, 10))
sns.histplot(df['Inches'])
# Out:
# <Axes: xlabel='Inches', ylabel='Count'>

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(df.corr(numeric_only = True), annot= True)
plt.show()
plt.savefig("test.png")

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from pandas.core.dtypes.common import is_numeric_dtype

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    if is_numeric_dtype(df[col]):
        continue
    else:
        df[col] = le.fit_transform(df[col])
        
df.head()
# Out:
#    laptop_ID  Company  Product  TypeName    Inches  ScreenResolution  Cpu
# 0   0.000000        1      300         4  0.385542                23   65  \
# 1   0.000758        1      301         4  0.385542                 1   63
# 2   0.001516        7       50         3  0.662651                 8   74
# 3   0.002274        1      300         4  0.638554                25   85
# 4   0.003033        1      300         4  0.385542                23   67
#
#    Ram  Memory  Gpu  OpSys  Weight  Price_euros
# 0    8       4   56      8      38     0.196741
# 1    8       2   50      8      35     0.122353
# 2    8      16   52      4      74     0.067679
# 3    1      29    8      8      71     0.398895
# 4    8      16   57      8      38     0.275038

# %%
df.drop(['laptop_ID'], axis = 1, inplace = True)
df.head()
# Out:
#    Company  Product  TypeName    Inches  ScreenResolution  Cpu  Ram  Memory
# 0        1      300         4  0.385542                23   65    8       4  \
# 1        1      301         4  0.385542                 1   63    8       2
# 2        7       50         3  0.662651                 8   74    8      16
# 3        1      300         4  0.638554                25   85    1      29
# 4        1      300         4  0.385542                23   67    8      16
#
#    Gpu  OpSys  Weight  Price_euros
# 0   56      8      38     0.196741
# 1   50      8      35     0.122353
# 2   52      4      74     0.067679
# 3    8      8      71     0.398895
# 4   57      8      38     0.275038

# %% [markdown]
# # Seaprating x,y

# %%
df.rename(columns={'Price_euros': 'Price'}, inplace=True)

# %%
df.head()
# Out:
#    Company  Product  TypeName    Inches  ScreenResolution  Cpu  Ram  Memory
# 0        1      300         4  0.385542                23   65    8       4  \
# 1        1      301         4  0.385542                 1   63    8       2
# 2        7       50         3  0.662651                 8   74    8      16
# 3        1      300         4  0.638554                25   85    1      29
# 4        1      300         4  0.385542                23   67    8      16
#
#    Gpu  OpSys  Weight     Price
# 0   56      8      38  0.196741
# 1   50      8      35  0.122353
# 2   52      4      74  0.067679
# 3    8      8      71  0.398895
# 4   57      8      38  0.275038

# %%
x = df.drop(['Price'], axis = 1)
y = df['Price']

# %%
xtrain, xtest, ytrain, ytest = tts(x, y, test_size = 0.3, random_state = 44)

# %%
xtrain.head()
# Out:
#       Company  Product  TypeName    Inches  ScreenResolution  Cpu  Ram
# 478         4      240         3  0.662651                 8   83    8  \
# 1066        2      380         1  0.867470                15   93    6
# 562         7      108         4  0.385542                19   47    1
# 503        10      205         3  0.469880                 0   37    5
# 266         2      600         0  0.385542                 7  106    8
#
#       Memory  Gpu  OpSys  Weight
# 478       10    5      5     113
# 1066      12   88      5     161
# 562       29   45      5      17
# 503       26   42      5     105
# 266       34   59      5      21

# %%
xtrain.shape
# Out:
# (912, 11)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lin = LinearRegression()

# %%
lin.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
lin_pred = lin.predict(xtest)
lin_pred
# Out:
# array([ 0.25832735,  0.12698886,  0.16884922,  0.13372428,  0.12099091,
#         0.15925135,  0.08658183,  0.16291579,  0.25122307,  0.14743007,
#         0.04792053,  0.19535254,  0.06644151,  0.13209523,  0.27609148,
#         0.24844947,  0.14609015,  0.14730428,  0.17918481,  0.27614383,
#         0.15646903,  0.27715727,  0.12945901,  0.14820134,  0.20469176,
#        -0.00939589,  0.13189952,  0.23251095,  0.14803034,  0.35323483,
#         0.07406606,  0.12342934,  0.13970558,  0.24332996,  0.25873672,
#         0.27103034,  0.09403649,  0.18590992,  0.13408521,  0.28524125,
#         0.26485815,  0.16854331,  0.11757285,  0.08368308,  0.12657333,
#         0.11812515,  0.2054075 ,  0.15319518,  0.23793428,  0.13927617,
#         0.11599607,  0.12296931,  0.17968936,  0.10164121,  0.26238239,
#         0.34442463,  0.01580181,  0.14063187,  0.21191487,  0.1689629 ,
#         0.18005844,  0.21445142,  0.06781108,  0.19678863,  0.17713988,
#         0.15647614,  0.12294855,  0.02791842,  0.01551084,  0.14814725,
#         0.24941941,  0.15502256, -0.05842496,  0.13582535,  0.14872297,
#         0.10356367,  0.26385669,  0.14702891,  0.12546194,  0.2712699 ,
#         0.26598283,  0.08973855,  0.14138446,  0.27710487,  0.02427442,
#         0.19039863,  0.05219045,  0.09579202,  0.14926554,  0.10953527,
#         0.03119604,  0.25111718,  0.17905173,  0.09248291,  0.07281555,
#         0.09001504,  0.1206832 ,  0.09809482,  0.20890242,  0.17124319,
#         0.12484358,  0.32354233,  0.17031297,  0.08963997,  0.08952387,
#         0.2498938 ,  0.18280888,  0.0885885 ,  0.11149761,  0.12636778,
#         0.21923704,  0.15163018,  0.04786498,  0.19162353,  0.01494676,
#         0.15078388,  0.21345166,  0.27692119,  0.20664412,  0.28045983,
#         0.16338527,  0.14922257,  0.19540039,  0.15357393,  0.05922154,
#         0.04977501,  0.18278998,  0.10613645,  0.28205305,  0.21747844,
#         0.18122593,  0.11319973,  0.14751026,  0.21669944, -0.0487873 ,
#         0.2200756 ,  0.15015755,  0.16792977,  0.1466813 ,  0.12314674,
#         0.21413015,  0.24301886,  0.23881158,  0.08181098,  0.26803797,
#         0.24777632,  0.03579669,  0.2082686 ,  0.19904603,  0.29096003,
#         0.21836696,  0.13509729,  0.11355   ,  0.25812859,  0.25877755,
#         0.19959809,  0.07406606, -0.02379049,  0.19564568,  0.14191095,
#         0.07406606,  0.29024198,  0.17264484, -0.03329102,  0.00893757,
#         0.09765598,  0.15019336,  0.03443743,  0.12769861,  0.12618801,
#         0.12358661, -0.03721572,  0.14325633,  0.10740487,  0.23960713,
#         0.11698429,  0.18718323,  0.1826567 ,  0.1370257 ,  0.10053562,
#         0.20027262,  0.28890964,  0.23344379,  0.1771706 ,  0.27072862,
#         0.1090136 ,  0.17955196,  0.15461441,  0.07981822,  0.13217803,
#         0.17170267,  0.19691928,  0.06099699,  0.08136833,  0.15480596,
#         0.18289329])

# %%
lin_score = lin.score(xtest,ytest)
lin_score
# Out:
# 0.4493283944176577

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import LabelEncoder
from pandas.core.dtypes.common import is_numeric_dtype

# %%
lin_mse = mean_squared_error(ytest, lin_pred)
lin_mse
# Out:
# 0.008622040348056007

# %%
lin_mae = mean_absolute_error(ytest, lin_pred)
lin_mae
# Out:
# 0.06505354504125853

# %% [markdown]
# # Decision tree

# %%
de = DecisionTreeRegressor()

# %%
de.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
de_pred = de.predict(xtest)
de_pred
# Out:
# array([0.44303797, 0.09367089, 0.19763713, 0.1571308 , 0.0751038 ,
#        0.2178903 , 0.10565401, 0.14409114, 0.19679325, 0.15443038,
#        0.25670886, 0.18869198, 0.04979072, 0.12067511, 0.37890295,
#        0.51746835, 0.10886076, 0.13265823, 0.17130802, 0.31308017,
#        0.27503797, 0.26582278, 0.22362869, 0.21910549, 0.09220591,
#        0.05316456, 0.09483038, 0.14092827, 0.03291139, 0.47156118,
#        0.04979072, 0.13924051, 0.20303797, 0.28742616, 0.39240506,
#        0.28202532, 0.08185654, 0.16351055, 0.21147679, 0.37518987,
#        0.2742616 , 0.16455696, 0.14778059, 0.05483544, 0.06956793,
#        0.09468354, 0.29974684, 0.03966245, 0.28962025, 0.08691983,
#        0.11105485, 0.29130802, 0.23898734, 0.03198481, 0.32877637,
#        0.34177215, 0.03864979, 0.04978903, 0.15611814, 0.07970802,
#        0.27932489, 0.29974684, 0.18649789, 0.12236287, 0.10044726,
#        0.04978903, 0.09704641, 0.04921857, 0.02092827, 0.09535865,
#        0.35864979, 0.10886076, 0.05854852, 0.07848101, 0.14767932,
#        0.06295359, 0.37890295, 0.14767932, 0.10481013, 0.45752911,
#        0.2742616 , 0.08860759, 0.08793249, 0.37518987, 0.03788861,
#        0.12978903, 0.06936709, 0.17130802, 0.11223629, 0.01890295,
#        0.01417722, 0.32413165, 0.33716793, 0.12067511, 0.03291139,
#        0.03459916, 0.0649789 , 0.08455696, 0.17070549, 0.19763713,
#        0.06329114, 0.42295359, 0.17000338, 0.00371308, 0.00590717,
#        0.20742616, 0.17641181, 0.03459916, 0.08708861, 0.08843882,
#        0.08725738, 0.14767932, 0.1585654 , 0.27932489, 0.04921857,
#        0.20742616, 0.15679325, 0.03291139, 0.10227848, 0.0364557 ,
#        0.09220591, 0.10565401, 0.38396624, 0.13552743, 0.19822447,
#        0.11223629, 0.34632911, 0.16351055, 0.26936709, 0.39240506,
#        0.27503797, 0.04555274, 0.07831224, 0.03628692, 0.02885907,
#        0.22042194, 0.31493671, 0.08523207, 0.02936709, 0.05864473,
#        0.01991561, 0.29046414, 0.02632911, 0.05654008, 0.20624473,
#        0.21012658, 0.12236287, 0.17485232, 0.79746835, 0.11898903,
#        0.0492827 , 0.04979072, 0.05316456, 0.21012658, 0.18582278,
#        0.04979072, 0.36523207, 0.22042194, 0.05485232, 0.05316456,
#        0.13924051, 0.19679325, 0.06936709, 0.05333333, 0.0649789 ,
#        0.21910549, 0.05854852, 0.15003376, 0.05485232, 0.27932489,
#        0.20303797, 0.12506329, 0.08118143, 0.17535865, 0.09721519,
#        0.13080169, 0.21839662, 0.89873418, 0.07831224, 0.2742616 ,
#        0.05900928, 0.16776371, 0.10886076, 0.07156118, 0.06329114,
#        0.04979072, 0.11915612, 0.02548523, 0.01890295, 0.09721519,
#        0.14666667])

# %%
de_score = de.score(xtest,ytest)
de_score
# Out:
# 0.7304996098213218

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(de,filled=True,rounded =True,feature_names =x.columns)
plt.savefig('tree.png',dpi=1200)

# %%
de_mse = mean_squared_error (ytest, de_pred)
de_mse
# Out:
# 0.004219653264090343

# %%
de_mae = mean_absolute_error(ytest, de_pred)
de_mae
# Out:
# 0.0381510829097737

# %% [markdown]
# # KNN

# %%
knn = KNeighborsRegressor()

# %%
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsRegressor()

# %%
knn_pred = knn.predict(xtest)
knn_pred
# Out:
# array([0.43382278, 0.14224473, 0.20536675, 0.13113924, 0.06501266,
#        0.13414346, 0.09040844, 0.1689789 , 0.22024776, 0.16714262,
#        0.18595781, 0.23858228, 0.08201316, 0.13778903, 0.21799156,
#        0.34904641, 0.14464169, 0.18206684, 0.25940928, 0.28168776,
#        0.24271696, 0.20111392, 0.22635949, 0.19836624, 0.10524219,
#        0.08855932, 0.05316456, 0.10217722, 0.01657384, 0.27837941,
#        0.08201316, 0.1375443 , 0.14463966, 0.23064979, 0.43382278,
#        0.20020253, 0.10939747, 0.17966582, 0.18686684, 0.29091376,
#        0.15544304, 0.20982245, 0.11806211, 0.06622211, 0.08752709,
#        0.0852962 , 0.25620253, 0.04280101, 0.30338093, 0.0585654 ,
#        0.16879764, 0.09022751, 0.149333  , 0.08052354, 0.21535865,
#        0.28854346, 0.03590447, 0.05908996, 0.23149367, 0.11281924,
#        0.1670211 , 0.28270042, 0.18597131, 0.14936709, 0.07648608,
#        0.08654852, 0.147173  , 0.06404118, 0.08489451, 0.12347848,
#        0.38364523, 0.14464169, 0.04013502, 0.06457046, 0.18727392,
#        0.07567561, 0.21711392, 0.17415831, 0.09986464, 0.31820624,
#        0.32661603, 0.13841283, 0.06585654, 0.29091376, 0.05238515,
#        0.25164557, 0.04467848, 0.06689924, 0.11788017, 0.24114768,
#        0.08654852, 0.08349603, 0.38364523, 0.05088101, 0.2492827 ,
#        0.30675072, 0.07466667, 0.14869198, 0.13120675, 0.02481013,
#        0.44229198, 0.2634427 , 0.19527426, 0.22555274, 0.12422819,
#        0.28297046, 0.06830616, 0.11598312, 0.09986464, 0.15020793,
#        0.14486008, 0.20398312, 0.15105485, 0.22635949, 0.19544304,
#        0.17697857, 0.15643646, 0.02592068, 0.08327426, 0.05279325,
#        0.24163072, 0.07295224, 0.269333  , 0.05387342, 0.18581873,
#        0.07792304, 0.26332489, 0.17966582, 0.13389873, 0.36613873,
#        0.24648101, 0.06080203, 0.11804253, 0.07232101, 0.04280101,
#        0.18733806, 0.21352236, 0.07385654, 0.06568776, 0.05426059,
#        0.01292827, 0.2764557 , 0.01937215, 0.1424135 , 0.15875105,
#        0.21352236, 0.12426802, 0.17105688, 0.43382278, 0.32354363,
#        0.0946157 , 0.08201316, 0.06830616, 0.21905823, 0.24013502,
#        0.08201316, 0.26332489, 0.21059916, 0.0544665 , 0.08349603,
#        0.1302616 , 0.14423629, 0.04432068, 0.04926076, 0.05719325,
#        0.17687662, 0.04050633, 0.11764051, 0.04364557, 0.1670211 ,
#        0.14957333, 0.1654346 , 0.22875949, 0.19183122, 0.07308186,
#        0.15740084, 0.28281249, 0.47333738, 0.11804253, 0.29765401,
#        0.12109435, 0.18764557, 0.13515612, 0.14285232, 0.07767089,
#        0.08062042, 0.11895325, 0.14281451, 0.03749097, 0.16755781,
#        0.0909708 ])

# %%
knn_score = knn.score(xtest, ytest)
knn_score
# Out:
# 0.6693672146096494

# %%
knn_mse =  mean_squared_error (ytest, knn_pred)
knn_mse
# Out:
# 0.005176822605572813

# %%
knn_mae = mean_absolute_error(ytest, knn_pred)
knn_mae
# Out:
# 0.04398667400476976

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor()

# %%
rf.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor()

# %%
rf_pred = rf.predict(xtest)
rf_pred
# Out:
# array([0.36310083, 0.10331477, 0.15904412, 0.13654069, 0.07335902,
#        0.18008857, 0.10049485, 0.14317347, 0.19452633, 0.15112044,
#        0.18926003, 0.2189092 , 0.05947716, 0.12672061, 0.32009332,
#        0.40768923, 0.14348513, 0.17745362, 0.20070154, 0.3132746 ,
#        0.2312451 , 0.230437  , 0.22247084, 0.1859497 , 0.1004065 ,
#        0.03610245, 0.0669105 , 0.15835443, 0.02848037, 0.41500201,
#        0.05511811, 0.14554091, 0.14851016, 0.30573813, 0.33225509,
#        0.26377178, 0.17477148, 0.15791337, 0.25796731, 0.30382316,
#        0.26337131, 0.20597703, 0.15295526, 0.0584454 , 0.0854614 ,
#        0.08806668, 0.2812948 , 0.04392883, 0.29475354, 0.08459078,
#        0.11346804, 0.17512395, 0.23148684, 0.0313149 , 0.3238109 ,
#        0.34051134, 0.04113381, 0.06752317, 0.21710501, 0.0661079 ,
#        0.07683848, 0.14444302, 0.01956459, 0.1712225 , 0.08074199,
#        0.08607696, 0.06545311, 0.22161197, 0.11792935, 0.14525278,
#        0.09727188, 0.1575012 , 0.09011605, 0.1851118 , 0.15507325,
#        0.16502186, 0.25696738, 0.15146101, 0.09161414, 0.03113028,
#        0.01954982, 0.21439257, 0.29283392, 0.01249327, 0.11689907,
#        0.27946758, 0.05570506, 0.06297828, 0.1291726 , 0.26954692,
#        0.06375843, 0.02319482, 0.33301818, 0.09370834, 0.24406616,
#        0.37627354, 0.08154896, 0.17590255, 0.10768702, 0.0734806 ,
#        0.43117365, 0.2111988 , 0.26446935, 0.21481851, 0.10357249,
#        0.34612535, 0.05449278, 0.13506543, 0.06741276, 0.17151328,
#        0.07251828, 0.14790697, 0.21335857, 0.2395643 , 0.17728224,
#        0.24760083, 0.16292064, 0.02504361, 0.11083085, 0.04451146,
#        0.09878567, 0.08953846, 0.39390846, 0.10820999, 0.19390278,
#        0.10287014, 0.31314481, 0.1588494 , 0.1613097 , 0.35575608,
#        0.22947414, 0.0435803 , 0.10201592, 0.03340277, 0.03106441,
#        0.20206552, 0.28145671, 0.0838149 , 0.07080954, 0.07595858,
#        0.01758378, 0.21748678, 0.02306498, 0.10164689, 0.20683749,
#        0.24782582, 0.19399046, 0.18824785, 0.57547151, 0.22807629,
#        0.05306974, 0.05511811, 0.04773043, 0.24417215, 0.18745433,
#        0.05511811, 0.37198007, 0.23037656, 0.05978719, 0.0505292 ,
#        0.12604565, 0.1748717 , 0.06582721, 0.0514349 , 0.0705158 ,
#        0.19494886, 0.05346897, 0.16721588, 0.05018597, 0.25309352,
#        0.14364901, 0.13544916, 0.09731424, 0.17944565, 0.10604604,
#        0.15265738, 0.22095684, 0.72124037, 0.09472727, 0.29118425,
#        0.08427689, 0.18933624, 0.121884  , 0.0884028 , 0.07772452,
#        0.05997397, 0.11695234, 0.04122795, 0.02055578, 0.1680269 ,
#        0.11550002])

# %%
rf_score = rf.score(xtest, ytest)
rf_score
# Out:
# 0.8585480796235749

# %%
rf_mse =mean_squared_error(ytest, rf_pred)
rf_mse
# Out:
# 0.0022147576748683014

# %%
rf_mae = mean_absolute_error(ytest, rf_pred)
rf_mae
# Out:
# 0.028720003975525262

# %% [markdown]
# # Compare

# %%
Score_compare = pd.DataFrame({'Actual': ytest, 'Linear Regression': lin_score, 'Decision Tree': de_score, 'Random Forest': rf_score, 'KNN': knn_score})
Score_compare
# Out:
#         Actual  Linear Regression  Decision Tree  Random Forest       KNN
# 494   0.184810           0.449328         0.7305       0.858548  0.669367
# 1275  0.093671           0.449328         0.7305       0.858548  0.669367
# 715   0.115286           0.449328         0.7305       0.858548  0.669367
# 772   0.142785           0.449328         0.7305       0.858548  0.669367
# 1206  0.068354           0.449328         0.7305       0.858548  0.669367
# ...        ...                ...            ...            ...       ...
# 496   0.122346           0.449328         0.7305       0.858548  0.669367
# 376   0.063966           0.449328         0.7305       0.858548  0.669367
# 882   0.029367           0.449328         0.7305       0.858548  0.669367
# 255   0.130802           0.449328         0.7305       0.858548  0.669367
# 883   0.083544           0.449328         0.7305       0.858548  0.669367
#
# [391 rows x 5 columns]

# %%
Pred_compare = pd.DataFrame({'Actual': ytest, 'Linear Regression': lin_pred, 'Decision Tree': de_pred, 'Random Forest': rf_pred, 'KNN': knn_pred})
Pred_compare
# Out:
#         Actual  Linear Regression  Decision Tree  Random Forest       KNN
# 494   0.184810           0.258327       0.443038       0.363101  0.433823
# 1275  0.093671           0.126989       0.093671       0.103315  0.142245
# 715   0.115286           0.168849       0.197637       0.159044  0.205367
# 772   0.142785           0.133724       0.157131       0.136541  0.131139
# 1206  0.068354           0.120991       0.075104       0.073359  0.065013
# ...        ...                ...            ...            ...       ...
# 496   0.122346           0.196919       0.119156       0.116952  0.118953
# 376   0.063966           0.060997       0.025485       0.041228  0.142815
# 882   0.029367           0.081368       0.018903       0.020556  0.037491
# 255   0.130802           0.154806       0.097215       0.168027  0.167558
# 883   0.083544           0.182893       0.146667       0.115500  0.090971
#
# [391 rows x 5 columns]

# %%
compare_score = pd.DataFrame({'Model': ['Linear Regression', 'Dession Tree', 'KNN', 'Random Forest'], 'Accuracy': [lin_score,de_score,knn_score,rf_score]})

# %%
compare_score
# Out:
#                Model  Accuracy
# 0  Linear Regression  0.449328
# 1       Dession Tree  0.730500
# 2                KNN  0.669367
# 3      Random Forest  0.858548

# %%
data1 = pd.DataFrame({
    'Name':['Accuracy'],
    'Linear Regression': [lin_score],
    'DT': [de_score],
    'KNN':[knn_score],
    'Random forest': [rf_score]})
data1.head()
# Out:
#        Name  Linear Regression      DT       KNN  Random forest
# 0  Accuracy           0.449328  0.7305  0.669367       0.858548

# %%
data1.plot(x="Name", y=["Linear Regression", "DT","KNN","Random forest"], kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %%
df = pd.DataFrame({
    'Name':['Linear Regression', 'Dession Tree','KNN','Random Forest'],
    'Accuracy Score':[lin_score,de_score, knn_score,rf_score],
    'Mean Absolute Error': [lin_mae,de_mae, knn_mae,rf_mae],
    'Mean Squared Error':[lin_mse,de_mse, knn_mse,rf_mse]})
df.head()
# Out:
#                 Name  Accuracy Score  Mean Absolute Error  Mean Squared Error
# 0  Linear Regression        0.449328             0.065054            0.008622
# 1       Dession Tree        0.730500             0.038151            0.004220
# 2                KNN        0.669367             0.043987            0.005177
# 3      Random Forest        0.858548             0.028720            0.002215

# %%
df.plot(x="Name", y=["Accuracy Score","Mean Absolute Error","Mean Squared Error"], kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %%
df = pd.DataFrame(data = np.random.random(size=(4,4)), columns = ['Linear','Dession Tree','KNN','Random Forest'])

df.plot(kind='bar')
plt.show()

# %%
df = pd.DataFrame(data = np.random.random(size=(4,4)), columns = ['Linear Regression','DT','KNN','Random forest'])

sns.boxplot(x="variable", y="value", data=pd.melt(df))

plt.show()
