# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_excel("shop.xlsx")
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull()
# Out:
#     Marketing Spend  Administration  Transport   Area  Profit
# 0             False           False      False  False   False
# 1             False           False      False  False   False
# 2             False           False      False  False   False
# 3             False           False      False  False   False
# 4             False           False      False  False   False
# 5             False           False      False  False   False
# 6             False           False      False  False   False
# 7             False           False      False  False   False
# 8             False           False      False  False   False
# 9             False           False      False  False   False
# 10            False           False      False  False   False
# 11            False           False      False  False   False
# 12            False           False      False  False   False
# 13            False           False      False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %% [markdown]
# # Measure Of Central Tendencyy

# %%
df.Transport.mean()
# Out:
# 215331.7324489796

# %%
df.Transport.median()
# Out:
# 214634.81

# %%
df.Area.mode() #mode hoilo j value ta repeat hoise oita dkhabe
# Out:
# 0      Ctg
# 1    Dhaka
# Name: Area, dtype: object

# %%
df.describe()
# Out:
#        Marketing Spend  Administration      Transport         Profit
# count        50.000000       50.000000      49.000000      50.000000
# mean      73721.615600   121344.639600  215331.732449  112012.639200
# std       45902.256482    28017.802755  119665.391550   40306.180338
# min           0.000000    51283.140000       0.000000   14681.400000
# 25%       39936.370000   103730.875000  134050.070000   90138.902500
# 50%       73051.080000   122699.795000  214634.810000  107978.190000
# 75%      101602.800000   144842.180000  299737.290000  139765.977500
# max      165349.200000   182645.560000  471784.100000  192261.830000

# %%
import seaborn as sns

# %%
sns.histplot(df[["Profit"]]) #histplot diye konta koto br reapet hoise oita graph dye dekhaise
# Out:
# <Axes: ylabel='Count'>

# %%
df.corr(numeric_only=True) #corrr hoilo co relation means ekta col er value chang hoile onno tar upr kmn impact pore
# Out:
#                  Marketing Spend  Administration  Transport    Profit
# Marketing Spend         1.000000        0.230437   0.718574  0.937948
# Administration          0.230437        1.000000   0.009534  0.200717
# Transport               0.718574        0.009534   1.000000  0.782578
# Profit                  0.937948        0.200717   0.782578  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True),annot = True) # annot dye value gula dekhte pbo
plt.savefig("Fig.png")

# %% [markdown]
# # Handle NAN Value (NAN= null)

# %%
Mean_Transport = df.Transport.mean()

# %%
Mean_Transport
# Out:
# 215331.7324489796

# %%
df.Transport = df.Transport.fillna(Mean_Transport) #  fillna dye jkhne jekhne null chilo sekhne Mean_Transport er value ta bosailm

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df[18:20] # 19 noline e trnsport e null chilo true tai oikhne avarage ta bosay diye null value hndl krse
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 18         91749.16       114175.79  294919.570000  Rangpur  124266.90
# 19         86419.70       153514.11  215331.732449    Dhaka  122776.86

# %%
df.Transport.iloc[19] #jst ekta line dekhar jnno
# Out:
# 215331.7324489796

# %%
df1 =df.copy()
df2 =df.copy()
df3 =df.copy()
df4 =df.copy()
df5 =df.copy()
df6 =df.copy()
df7 =df.copy()
df8 =df.copy()
df9 =df.copy()
df10 =df.copy()

# %% [markdown]
# # Without Encoding

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
area1 =df.Area.unique()
area1
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df.Area= df.Area.replace(['Dhaka', 'Ctg', 'Rangpur'],[1,2,3])
df.Area
# Out:
# 0     1
# 1     2
# 2     3
# 3     1
# 4     3
# 5     1
# 6     2
# 7     3
# 8     1
# 9     2
# 10    3
# 11    2
# 12    3
# 13    2
# 14    3
# 15    1
# 16    2
# 17    1
# 18    3
# 19    1
# 20    2
# 21    1
# 22    3
# 23    3
# 24    1
# 25    2
# 26    3
# 27    1
# 28    3
# 29    1
# 30    3
# 31    1
# 32    2
# 33    3
# 34    2
# 35    1
# 36    3
# 37    2
# 38    1
# 39    2
# 40    2
# 41    3
# 42    2
# 43    1
# 44    2
# 45    1
# 46    3
# 47    2
# 48    1
# 49    2
# Name: Area, dtype: int64

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %%
df.corr()
# Out:
#                  Marketing Spend  Administration  Transport      Area
# Marketing Spend         1.000000        0.230437   0.718001  0.037930  \
# Administration          0.230437        1.000000   0.009402  0.003026
# Transport               0.718001        0.009402   1.000000  0.097937
# Area                    0.037930        0.003026   0.097937  1.000000
# Profit                  0.937948        0.200717   0.781996  0.048471
#
#                    Profit
# Marketing Spend  0.937948
# Administration   0.200717
# Transport        0.781996
# Area             0.048471
# Profit           1.000000

# %% [markdown]
# # Lebel Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1.Area =le.fit_transform(df1.Area)
df1.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # Using Loop

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for col in df2.columns:
    if df2[col].dtype == np.number:
        continue
    else:
        df2[col]= le.fit_transform(df2[col])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %% [markdown]
# # Another Way

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df3.columns:
    if is_numeric_dtype(df3[i]):
        continue
    else:
        df3[i]=le.fit_transform(df3[i])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # One Hot Encoding

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
dummy = pd.get_dummies(df4['Area'],columns = df4.Area.unique)
dummy
# Out:
#       Ctg  Dhaka  Rangpur
# 0   False   True    False
# 1    True  False    False
# 2   False  False     True
# 3   False   True    False
# 4   False  False     True
# 5   False   True    False
# 6    True  False    False
# 7   False  False     True
# 8   False   True    False
# 9    True  False    False
# 10  False  False     True
# 11   True  False    False
# 12  False  False     True
# 13   True  False    False
# 14  False  False     True
# 15  False   True    False
# 16   True  False    False
# 17  False   True    False
# 18  False  False     True
# 19  False   True    False
# 20   True  False    False
# 21  False   True    False
# 22  False  False     True
# 23  False  False     True
# 24  False   True    False
# 25   True  False    False
# 26  False  False     True
# 27  False   True    False
# 28  False  False     True
# 29  False   True    False
# 30  False  False     True
# 31  False   True    False
# 32   True  False    False
# 33  False  False     True
# ...

# %%
dummy.head()
# Out:
#      Ctg  Dhaka  Rangpur
# 0  False   True    False
# 1   True  False    False
# 2  False  False     True
# 3  False   True    False
# 4  False  False     True

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df4.drop("Area",axis =1 , inplace =True)

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %% [markdown]
# # Dummy Variable Trap

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
dummy = pd.get_dummies(df5["Area"],columns =df5.Area.unique,drop_first= True ,prefix = 'Area' )

# %%
dummy.head()
# Out:
#    Area_Dhaka  Area_Rangpur
# 0        True         False
# 1       False         False
# 2       False          True
# 3        True         False
# 4       False          True

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df6= pd.concat([df4,dummy],axis=1)
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka
# 0        114523.61       136897.80  471784.10  192261.83        True  \
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    Area_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %% [markdown]
# # One Hot Encoding Using Loop

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
cols = ["Area"]
for col in cols:
    dummy =pd.get_dummies(df7[col],drop_first= True ,prefix = "Area")
    df8 = pd.concat([df,dummy],axis =1).drop(col,axis=1)
    
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka
# 0        114523.61       136897.80  471784.10  192261.83        True  \
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    Area_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %% [markdown]
# # Ordinal Encoding

# %%
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
city =df9.Area.unique()
city
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
od = OrdinalEncoder(categories=[city] )

# %%
encoded_values= od.fit_transform(df9[['Area']])
encoded_values
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.]])

# %%
encoded_values =pd.DataFrame(encoded_values,columns=['Area'])

# %%
encoded_values.head()
# Out:
#    Area
# 0   0.0
# 1   1.0
# 2   2.0
# 3   0.0
# 4   2.0

# %%
df9= pd.concat([df9.drop('Area',axis=1 ),encoded_values],axis=1)

# %%
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area
# 0        114523.61       136897.80  471784.10  192261.83   0.0
# 1        162597.70       151377.59  443898.53  191792.06   1.0
# 2        153441.51       101145.55  407934.54  191050.39   2.0
# 3        144372.41       118671.85  383199.62  182901.99   0.0
# 4        142107.34        91391.77  366168.42  166187.94   2.0
